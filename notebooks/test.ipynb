# %%
import httpx
import requests
import json
import pandas as pd
from datetime import datetime
from tzlocal import get_localzone
from fastapi import HTTPException

"""
Decodes Canvas API responses into DataFrames for downstream use.
"""

def parse_iso_timestamps(data : pd.DataFrame) -> pd.DataFrame:
    """
    Replace all string timestamps in a DataFrame with datetime objects.
    All timestamps must comply with ISO-8601.

    Args:
        data (DataFrame): DataFrame containing ISO-8601 string timestamps.

    Returns:
        data (DataFrame): DataFrame containing datetime timestamps.
    """

    # Obtain all columns which can be converted
    # into a timestamp through ugly brute-forcing
    timestamp_columns = []
    for key, value in data.iloc[0].to_dict().items():
        if type(value) is str:
            try:
                datetime.fromisoformat(value)
                timestamp_columns.append(key)
            except:
                pass

    def isotime_to_timestamp(value : str | None, use_local_timezone : bool = True, as_string : bool = False):
        if type(value) is not str: return None
        
        time = datetime.fromisoformat(value)
        if use_local_timezone:
            time = time.astimezone(get_localzone())

        if as_string:
            time = time.strftime("%A, %d %B %Y, %I:%M %p")
            
        return time
    
    for column in timestamp_columns:
        data[column] = data[column].map(isotime_to_timestamp)

    return data

def process_canvas_dataframe(response : pd.DataFrame) -> pd.DataFrame:
    response = parse_iso_timestamps(response) # Convert string timestamps to object
    response = response.dropna(axis=1, how="all") # Drop columns with entirely NA values
    return response
    
def decode_canvas_response(response : requests.Response | httpx.Response | list[dict]) -> pd.DataFrame:
    """
    Converts raw Canvas API response into a DataFrame for downstream use,
    or raises Exception if the response is invalid.

    Args:
        response (Response | dict): The API response obtained from Canvas.

    Returns:
        response_data (DataFrame): The response data.
    """
    
    if type(response) is list:
        response_list = response

    elif type(response) is requests.Response or type(response) is httpx.Response:
        if not response.status_code == 200:
            raise HTTPException(
                status_code = response.status_code,
                detail=response.text
            )

        try:
            content = response.content
            if not content: raise HTTPException(status_code=400, detail="Canvas API response contained no content")
        except: raise HTTPException(status_code=400, detail="Canvas API response contained no content")

        # Canvas API will always respond in JSON format,
        # but we obtain the response in bytes, so it
        # must be decoded into a raw string and then
        # encoded into a JSON object.
        
        content = content.decode('utf-8')
        response_json : dict | list = json.loads(content)

        if type(response_json) is list:
            response_list = response_json
        else:
            response_list = [response_json]

    else:
        raise ValueError("Response must be either a requests/httpx Response object or a list of dicts.")
    
    # Empty response
    if not response_list:
        return pd.DataFrame([])
    
    response_df = pd.DataFrame(response_list)
    response_df = process_canvas_dataframe(response_df)
    return response_df

async def query_canvas(path : str, magic : str, provider : str, params : dict = {}, max_items : int = 100, timeout : int = 60) -> pd.DataFrame:
    """
    Obtain data from the Canvas API using a HTTP GET request.
    See https://developerdocs.instructure.com/services/canvas/resources for more information.

    Args:
        path (str): The Canvas v1 API path suffix. E.g., "courses" for "provider.instructure.com/api/v1/courses"
        magic (str): The magic key generated by the wizard to enter the gate.
        provider (str): The name of the institution which has installed Canvas in lowercase.
        params (dict, optional): Additional request parameters for the API to use. Specific to each resource. Defaults to an empty dictionary.
        max_items (int, optional): The maximum number of items to return. Defaults to 100.
        timeout (int, optional): How many seconds to allow the API to respond before timing out. Defaults to 60.

    Raises:
        HTTPException: If the request does not return status 200 or times out, a HTTPException is raised.
    
    Returns:
        data (DataFrame): The response from Canvas in DataFrame form.
    """
    params["access_token"] = magic
    params["per_page"] = max_items
    
    path = f"https://{provider}.instructure.com/api/v1/{path}"

    try:
        async with httpx.AsyncClient(timeout=timeout) as client:
            response = await client.get(path, params=params)
    except httpx.ReadTimeout:
        raise HTTPException(
            status_code = 408,
            detail = f"{provider.capitalize()} Canvas API GET request timed out after {timeout} seconds. Request URL: {path}"
        ) 
    
    if not response.status_code == 200:
        raise HTTPException(
            status_code = response.status_code,
            detail=response.text
        )
    
    try:
        data : pd.DataFrame = decode_canvas_response(response)
    except Exception as e:
        raise HTTPException(
            status_code = 500,
            detail = str(e)
        )
    
    return data

# %%
# Obtain Canvas access token from .env file

import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
token = os.environ.get("TOKEN")

# %%
params = {"include":"term"}
raw_units = await query_canvas(path="courses", magic=token, provider="swinburne", max_items=50, params=params)

# %%
raw_units = await query_canvas(path="courses", magic=token, provider="swinburne", max_items=50, params=params)
# Out:
#        id                                               name  \
# 0   61564                              1] Capstone Project B
# 1   52786                                            1] CTIP
# 2   65692                                       1] Honours B
# 3   49155                                     1] Intro to AI
# 4   43430                            1] Intro to Programming
# 5   66785                                  1] Linear Algebra
# 6   54180                    2] Cloud Computing Architecture
# 7   44774                                    2] Comp Systems
# 8   48754                           2] Comp Tech Des Project
# 9   40745                              2] CT Inquiry Project
# 10  61569                             2] Intelligent Systems
# 11  63937                                 2] Prof Internship
# 12  61563                              3] AI for Engineering
# 13  50698                        3] Criminology Fundamentals
# 14  40727                            3] Networks & Switching
# 15  49150                      4] Indigenous Context Project
# 16  61616                               4] Preliminary Maths
# 17  52845  4] Prototyping and Interdisciplinary Collabora...
# 18  41658                            4] User Centered Design
# 19  32049                    5] Learning and Academic Skills
# 20  56952                           Applied Machine Learning
# 21  58248                                 Capstone Project A
# 22  52834                  Career Confidence and Connections
# 23  45070                                 DONE - Game Design
# 24  44776                                         DONE - OOP
# 25  60285                      ORG-COM-AI-Academic Integrity
# 26  64605         ORG-COM-ICC-Indigenous Cultural Competency
# 27  38972                      ORG-COM-Talking About Consent
# 28  18878                ORG-STU-Canvas support for students
# 29  18067                          ORG-STU-Library Resources
# 30  60289                                   ORG-STU-SoHS-HUB
# 31  60290                                 ORG-STU-SoSCET-HUB
# 32  23234                       ORG-STU-Swinburne Residences
# 33  56983                              Software Arch. & Des.
#
#                                           course_code  account_id  \
# 0   2024-HS2-COS40006-Computing Technology Project...          85
# 1   2023-HS2-COS30049-Computing Technology Innovat...          85
# 2         2025-HS2-NPS40013-Honours Project Part B-H1          79
# 3   2023-HS1-COS30019-Introduction to Artificial I...          85
# 4    2022-HS1-COS10009-Introduction to Programming-H1          85
# 5   2025-HS1-MTH10013-Linear Algebra and Applicati...          78
# 6   2023-HS2-COS20019-Cloud Computing Architecture-H1          85
# 7               2022-HS2-COS10004-Computer Systems-H1          85
# 8   2023-HS1-COS20031-Computing Technology Design ...          85
# 9   2022-HS1-COS10026-Computing Technology Inquiry...          85
# 10           2024-HS2-COS30018-Intelligent Systems-H1          85
# 11                2025 HS1 Professional Internship-H2         257
# 12  2024-HS2-COS40007-Artificial Intelligence for ...          85
# 13   2023-HS1-CRI10002-Fundamentals of Criminology-H1         168
# 14  2022-HS1-TNE10006/TNE60006-Networks and Switch...          86
# 15  2023-HS1-COS10025-Technology in an Indigenous ...          85
# 16       2024-HS2-MTH00007-Preliminary Mathematics-H1          78
# 17  2023-HS2-DES20057-Toolbox for Prototyping and ...          72
# 9                  587     False                 87.0  ...
# 10                 779     False                 87.0  ...
# 11                 946     False                 87.0  ...
# 12                 779      None                 87.0  ...
# 13                 683     False                 87.0  ...
# 14                 587     False                 87.0  ...
# 15                 683     False                 87.0  ...
# 16                 779     False                 87.0  ...
# 17                 715     False                 87.0  ...
# 18                 587     False                 87.0  ...
# 19                   1     False                  NaN  ...
# 20                 756     False                 87.0  ...
# 21                 756     False                 87.0  ...
# 22                 711     False                  NaN  ...
# 23                 600     False                 87.0  ...
# 24                 600     False                 87.0  ...
# 25                   1     False                  NaN  ...
# 26                   1     False                  NaN  ...
# 27                   1     False                  NaN  ...
# 28                   1     False                  0.0  ...
# 29                   1     False                  NaN  ...
# 30                   1     False                  NaN  ...
# 31                   1     False                  NaN  ...
# 32                   1     False                  NaN  ...
# 33                 756     False                 87.0  ...
#
#                                         original_name blueprint template  \
# 0    2024-HS2-COS40006-Computing Technology Project B     False    False
# 1   2023-HS2-COS30049-Computing Technology Innovat...     False    False
# 2            2025-HS2-NPS40013-Honours Project Part B     False    False
# 3   2023-HS1-COS30019-Introduction to Artificial I...     False    False
# 4       2022-HS1-COS10009-Introduction to Programming     False    False
# 5   2025-HS1-MTH10013-Linear Algebra and Applications     False    False
# 6      2023-HS2-COS20019-Cloud Computing Architecture     False    False
# 7                  2022-HS2-COS10004-Computer Systems     False    False
# 8   2023-HS1-COS20031-Computing Technology Design ...     False    False
# 9   2022-HS1-COS10026-Computing Technology Inquiry...     False    False
# 10              2024-HS2-COS30018-Intelligent Systems     False    False
# 11                   2025 HS1 Professional Internship     False    False
# 12  2024-HS2-COS40007-Artificial Intelligence for ...     False    False
# 13      2023-HS1-CRI10002-Fundamentals of Criminology     False    False
# 14  2022-HS1-TNE10006/TNE60006-Networks and Switch...     False    False
# 15  2023-HS1-COS10025-Technology in an Indigenous ...     False    False
# 16          2024-HS2-MTH00007-Preliminary Mathematics     False    False
# 17  2023-HS2-DES20057-Toolbox for Prototyping and ...     False    False
# 18     2022-HS1-COS20001/COS70004-User-Centred Design     False    False
# 19               ORG-STU-Learning and Academic Skills     False    False
# 20         2024-HS1-COS30082-Applied Machine Learning     False    False
# 21   2024-HS1-COS40005-Computing Technology Project A     False    False
# 22  2023-WIN-CAR10002-Building Career Confidence a...     False    False
# 23        2022-HS2-GAM10002-Principles of Game Design     False    False
# 24      2022-HS2-COS20007-Object Oriented Programming     False    False
# 25                                                NaN     False    False
# 26                                                NaN     False    False
# 27                                                NaN     False    False
# 28                                                NaN     False    False
# 29                                                NaN     False    False
# 30                                                NaN     False    False
# 31                                                NaN     False    False
# 32                                                NaN     False    False
# 33  2024-HS1-SWE30003-Software Architectures and D...     False    False
#
#                                           enrollments  hide_final_grades  \
# 0   [{'type': 'student', 'role': 'StudentEnrollmen...              False
# 1   [{'type': 'student', 'role': 'StudentEnrollmen...              False
# 2   [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 3   [{'type': 'student', 'role': 'StudentEnrollmen...              False
# 4   [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 5   [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 6   [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 7   [{'type': 'student', 'role': 'StudentEnrollmen...              False
# 8   [{'type': 'student', 'role': 'StudentEnrollmen...              False
# 9   [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 10  [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 11  [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 12  [{'type': 'student', 'role': 'StudentEnrollmen...              False
# 13  [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 14  [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 15  [{'type': 'student', 'role': 'StudentEnrollmen...              False
# 16  [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 17  [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 18  [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 19  [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 20  [{'type': 'student', 'role': 'StudentEnrollmen...              False
# 21  [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 22  [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 23  [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 24  [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 25  [{'type': 'student', 'role': 'StudentEnrollmen...              False
# 26  [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 27  [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 28  [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 29  [{'type': 'student', 'role': 'StudentEnrollmen...              False
# 30  [{'type': 'student', 'role': 'StudentEnrollmen...              False
# 31  [{'type': 'student', 'role': 'StudentEnrollmen...              False
# 32  [{'type': 'student', 'role': 'StudentEnrollmen...               True
# 33  [{'type': 'student', 'role': 'StudentEnrollmen...              False
#
#     workflow_state  restrict_enrollments_to_course_dates  \
# 0        available                                 False
# 1        available                                 False
# 2        available                                 False
# 3        available                                 False
# 4        available                                 False
# 5        available                                 False
# 6        available                                 False
# 7        available                                 False
# 8        available                                 False
# 9        available                                 False
# 10       available                                 False
# 11       available                                  True
# 12       available                                 False
# 13       available                                  True
# 14       available                                 False
# 15       available                                 False
# 16       available                                 False
# 17       available                                 False
# 18       available                                 False
# 19       available                                  True
# 20       available                                 False
# 21       available                                 False
# 22       available                                 False
# 23       available                                 False
# 24       available                                 False
# 25       available                                  True
# 26       available                                 False
# 27       available                                  True
# 28       available                                  True
# 29       available                                  True
# 30       available                                  True
# 31       available                                 False
# 32       available                                 False
# 33       available                                  True
#
#     overridden_course_visibility  locale course_format
# 0                            NaN     NaN           NaN
# 1                            NaN     NaN           NaN
# 2                            NaN     NaN           NaN
# 3                            NaN     NaN           NaN
# 4                                    NaN           NaN
# 5                            NaN     NaN           NaN
# 6                            NaN     NaN           NaN
# 7                                    NaN           NaN
# 8                            NaN     NaN           NaN
# 9                                    NaN           NaN
# 10                           NaN     NaN           NaN
# 11                           NaN     NaN           NaN
# 12                           NaN     NaN           NaN
# 13                           NaN     NaN           NaN
# 14                                 en-GB           NaN
# 15                           NaN     NaN           NaN
# 16                           NaN     NaN           NaN
# 17                           NaN     NaN           NaN
# 18                                    en           NaN
# 19                           NaN     NaN       blended
# 20                           NaN     NaN           NaN
# 21                           NaN   en-AU           NaN
# 22                           NaN     NaN           NaN
# 23                                   NaN           NaN
# 24                                   NaN           NaN
# 25                           NaN     NaN           NaN
# 26                           NaN     NaN           NaN
# 27                           NaN     NaN           NaN
# 28                                    en           NaN
# 29                           NaN     NaN           NaN
# 30                           NaN     NaN           NaN
# 31                           NaN     NaN           NaN
# 32                           NaN     NaN           NaN
# 33                           NaN     NaN           NaN
#
# [34 rows x 33 columns]

# %%
raw_terms = decode_canvas_response(raw_units["term"].to_list())
raw_terms.drop_duplicates(subset="id")
# Out:
#      id             name                  start_at                    end_at  \
# 0   779  2024 Semester 2 2024-07-15 00:00:00+10:00 2024-12-31 00:00:00+11:00
# 1   715  2023 Semester 2 2023-07-17 00:00:00+10:00 2024-01-02 00:00:00+11:00
# 2   948  2025 Semester 2 2025-07-21 00:00:00+10:00 2026-01-06 00:00:00+11:00
# 3   683  2023 Semester 1 2023-02-13 00:00:00+11:00 2023-08-01 00:00:00+10:00
# 4   587  2022 Semester 1 2022-02-21 11:00:00+11:00 2022-06-26 10:00:00+10:00
# 5   946  2025 Semester 1 2025-02-17 00:00:00+11:00 2025-08-05 00:00:00+10:00
# 7   600  2022 Semester 2 2022-07-25 00:00:00+10:00 2023-01-03 00:00:00+11:00
# 19    1     Default term                       NaT                       NaT
# 20  756  2024 Semester 1 2024-02-12 00:00:00+11:00 2024-07-30 00:00:00+10:00
# 22  711      2023 Winter 2023-06-05 00:00:00+10:00 2023-09-12 00:00:00+10:00
#
#    workflow_state                created_at
# 0          active 2023-10-04 14:25:02+11:00
# 1          active 2022-10-25 13:00:35+11:00
# 2          active 2024-06-20 15:20:32+10:00
# 3          active 2022-08-23 09:15:02+10:00
# 4          active 2021-06-07 08:51:01+10:00
# 5          active 2024-06-04 08:50:03+10:00
# 7          active 2021-09-06 12:58:30+10:00
# 19         active 2017-03-09 20:24:49+11:00
# 20         active 2023-06-06 10:18:33+10:00
# 22         active 2022-09-15 15:10:32+10:00
